# %%
import gandula
from gandula.utils.frames import get_shot_frames

# %%
frames = gandula.get_frames(
    '/Users/thiago/football/ufmg/gandula/_data/tracking/premier-league/22-23',
    4621,
)

# %%
gandula.view(frames[0])
# Out:
# <Axes: >

# %%
shot_frames = get_shot_frames(frames)

# %%
gandula.view(shot_frames[0])
# Out:
# <Axes: >
