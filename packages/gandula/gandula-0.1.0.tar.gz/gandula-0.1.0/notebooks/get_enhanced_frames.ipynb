# %%
import gandula

# %%
enhanced = gandula.get_enhanced_frames(
    '/Users/thiago/football/ufmg/gandula/_data/tracking/premier-league/22-23',
    4621,
)
# Out:
# Player 6889 (missedTouch) not found in frame 95700
# Player 191 (missedTouch) not found in frame 110281
# Player 197 (missedTouch) not found in frame 139391
# Player 6054 (target) not found in frame 174612
# Player 7170 (defender) not found in frame 174612

# %%
gandula.view(enhanced[0]['event'])
# Out:
# {'id': '6789499',
#  'endTime': 238.805,
#  'formattedGameClock': '00:00',
#  'game': {'id': '4621'},
#  'gameClock': 0.0,
#  'gameEvent': {'id': '6900047'},
#  'lastInGameEvent': 1,
#  'passingEvent': {'ballHeightType': <HeightType.GROUND: 'G'>,
#   'game': {'id': '4621'},
#   'gameEvent': {'id': '6900047'},
#   'id': '4523298',
#   'passAccuracyType': <PassAccuracyType.STANDARD: 'S'>,
#   'passBodyType': <BodyType.RIGHT_FOOT: 'R'>,
#   'passHighPointType': <HeightType.GROUND: 'G'>,
#   'passOutcomeType': <PassOutcomeType.COMPLETE: 'C'>,
#   'passPointX': 9.228,
#   'passPointY': 9.414,
#   'passType': <PassType.STANDARD_PASS: 'S'>,
#   'passerPlayer': {'id': '223'},
#   'possessionEvent': {'id': '6789499'},
#   'receiverBodyType': <BodyType.RIGHT_FOOT: 'R'>,
#   'receiverHeightType': <HeightType.GROUND: 'G'>,
#   'receiverPlayer': {'id': '231'},
#   'receiverPointX': -13.903,
#   'receiverPointY': -1.543,
#   'targetFacingType': <FacingType.GOAL: 'G'>,
# ...

# %%
gandula.view(enhanced[0]['frame'])
# Out:
# <Axes: >
